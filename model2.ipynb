# %%
# -*- coding: utf-8 -*-


import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np


# Make sure there is a GPU working
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 150 # Determine number of epoches
batch_size = 50 # Determine size of batch
learning_rate = 0.01 # Determine learning rate

# Process the images in advance
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomCrop(32),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()])

# Download CIFAR-10 dataset
trainset = torchvision.datasets.CIFAR10(root='../data/',
                                    train=True, 
                                    transform=transform,
                                    download=True)

testset = torchvision.datasets.CIFAR10(root='../data/',
                                    train=False, 
                                    transform=transforms.ToTensor())

# Load data set
trainloader = torch.utils.data.DataLoader(dataset=trainset,
                                    batch_size=batch_size,
                                    shuffle=True)

testloader = torch.utils.data.DataLoader(dataset=testset,
                                    batch_size=batch_size,
                                    shuffle=False)

# Here we define the construction of model

# Define the 3x3 convolution
def conv3x3(in_channels, out_channels, stride=1):
    return nn.Conv2d(in_channels, out_channels, kernel_size=3, 
                              stride=stride, padding=1, bias=False)

# Here is the Residual block of Resnet
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, downsample=None):
        super(ResidualBlock, self).__init__()
        self.conv1 = conv3x3(in_channels, out_channels, stride)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = conv3x3(out_channels, out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.downsample = downsample
        
    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        if self.downsample:
            residual = self.downsample(x)
        out += residual
        out = self.relu(out)
        return out

# The definination of the Resnet architecture
class ResNet(nn.Module):
    def __init__(self, block, layers, num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels = 16
        self.conv = conv3x3(3, 16)
        self.bn = nn.BatchNorm2d(16)
        self.relu = nn.ReLU(inplace=True)
        self.layer1 = self.make_layer(block, 16, layers[0])
        self.layer2 = self.make_layer(block, 32, layers[1], 2)
        self.layer3 = self.make_layer(block, 64, layers[2], 2)
        self.avg_pool = nn.AvgPool2d(8)
        self.fc = nn.Linear(64, num_classes)
        
    # Code of the function to constrcut the layers
    def make_layer(self, block, out_channels, blocks, stride=1):
        downsample = None
        if (stride != 1) or (self.in_channels != out_channels):
            downsample = nn.Sequential(
                conv3x3(self.in_channels, out_channels, stride=stride),
                nn.BatchNorm2d(out_channels))
        layers = []
        layers.append(block(self.in_channels, out_channels, stride, downsample))
        self.in_channels = out_channels
        for i in range(1, blocks):
            layers.append(block(out_channels, out_channels))
        return nn.Sequential(*layers)
    # Go to next step
    def forward(self, x):
        out = self.conv(x)
        out = self.bn(out)
        out = self.relu(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out


model = ResNet(ResidualBlock, [2, 2, 2]).to(device)
#Use to print out the model
#print("=" * 60)
#print(model)


total_params = sum(p.numel() for p in model.parameters())
print(f'number of Total Parameters:{total_params}')


#print("=" * 60)

# The funtion which calculates loss
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Update the learning rate
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# Train the dataset
total_step = len(trainloader)
curr_lr = learning_rate

# Train the model
for epoch in range(num_epochs):
    
    gt_labels = []
    pred_labels = []
    
    for i, (images, labels) in enumerate(trainloader):
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        
        #The predicted result, a tensor, is put on the cpu and converted into an array of numpy
        gt_labels.append(labels.cpu().data.numpy())
        
        # print(type(gt_labels))
        # print(gt_labels.shape)
        
        # Get the label of the vector with the maximum value.
        preds = torch.argmax(outputs, 1)
        pred_labels.append(preds.cpu().data.numpy())
        
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
 

    
    # Print out the accuracy
    gt_labels, pred_labels = np.concatenate(gt_labels), np.concatenate(pred_labels)
    acc = np.sum(gt_labels==pred_labels)/len(pred_labels)
    print("Epoch %d. Valid Loss: %f, Valid Acc: %f, " %(epoch, loss.item(), acc))
    

    # Delay learning rate
    if (epoch+1) % 20 == 0:
        curr_lr /= 3
        update_lr(optimizer, curr_lr)

# Test network model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in testloader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

   # print('Accuracy of the model on the test images: {} %'.format(100 * correct / total))

# Save the model
torch.save(model.state_dict(), 'resnet.ckpt')
# Out:
# Files already downloaded and verified
# number of Total Parameters:195738
# Epoch 0. Valid Loss: 1.163363, Valid Acc: 0.403800,
# Epoch 1. Valid Loss: 1.110881, Valid Acc: 0.613920,
# Epoch 2. Valid Loss: 0.719387, Valid Acc: 0.710540,
# Epoch 3. Valid Loss: 0.703548, Valid Acc: 0.758920,
# Epoch 4. Valid Loss: 0.683755, Valid Acc: 0.781340,
# Epoch 5. Valid Loss: 0.738543, Valid Acc: 0.801020,
# Epoch 6. Valid Loss: 0.593659, Valid Acc: 0.816860,
# Epoch 7. Valid Loss: 0.246728, Valid Acc: 0.827420,
# Epoch 8. Valid Loss: 0.313710, Valid Acc: 0.836100,
# Epoch 9. Valid Loss: 0.376280, Valid Acc: 0.844300,
# Epoch 10. Valid Loss: 0.579987, Valid Acc: 0.851500,
# Epoch 11. Valid Loss: 0.381355, Valid Acc: 0.857400,
# Epoch 12. Valid Loss: 0.403709, Valid Acc: 0.859620,
# Epoch 13. Valid Loss: 0.362236, Valid Acc: 0.867580,
# Epoch 14. Valid Loss: 0.341499, Valid Acc: 0.869940,
# Epoch 15. Valid Loss: 0.361626, Valid Acc: 0.875720,
# Epoch 16. Valid Loss: 0.185467, Valid Acc: 0.879040,
# Epoch 17. Valid Loss: 0.249711, Valid Acc: 0.881440,
# Epoch 18. Valid Loss: 0.369113, Valid Acc: 0.885780,
# Epoch 19. Valid Loss: 0.189760, Valid Acc: 0.888740,
# Epoch 20. Valid Loss: 0.509866, Valid Acc: 0.912560,
# Epoch 21. Valid Loss: 0.250818, Valid Acc: 0.918340,
# Epoch 22. Valid Loss: 0.167244, Valid Acc: 0.920580,
# Epoch 23. Valid Loss: 0.148129, Valid Acc: 0.924080,
# Epoch 24. Valid Loss: 0.121411, Valid Acc: 0.925340,
# Epoch 25. Valid Loss: 0.123872, Valid Acc: 0.928540,
# Epoch 26. Valid Loss: 0.349379, Valid Acc: 0.929100,
# Epoch 27. Valid Loss: 0.082708, Valid Acc: 0.930360,
# Epoch 28. Valid Loss: 0.186735, Valid Acc: 0.931940,
# Epoch 29. Valid Loss: 0.143824, Valid Acc: 0.932040,
# Epoch 30. Valid Loss: 0.162098, Valid Acc: 0.934600,
# Epoch 31. Valid Loss: 0.118667, Valid Acc: 0.932720,
# Epoch 32. Valid Loss: 0.081903, Valid Acc: 0.935900,
# Epoch 33. Valid Loss: 0.164192, Valid Acc: 0.936860,
# Epoch 34. Valid Loss: 0.284668, Valid Acc: 0.938180,
# Epoch 35. Valid Loss: 0.196621, Valid Acc: 0.939960,
# Epoch 36. Valid Loss: 0.166096, Valid Acc: 0.938940,
# Epoch 37. Valid Loss: 0.183181, Valid Acc: 0.940320,
# Epoch 38. Valid Loss: 0.265228, Valid Acc: 0.943320,
# Epoch 39. Valid Loss: 0.052014, Valid Acc: 0.942160,
# Epoch 40. Valid Loss: 0.160788, Valid Acc: 0.950920,
# Epoch 41. Valid Loss: 0.119949, Valid Acc: 0.956120,
# Epoch 42. Valid Loss: 0.264432, Valid Acc: 0.954060,
# Epoch 43. Valid Loss: 0.325773, Valid Acc: 0.956160,
# Epoch 44. Valid Loss: 0.258156, Valid Acc: 0.956040,
# Epoch 45. Valid Loss: 0.071176, Valid Acc: 0.955600,
# Epoch 46. Valid Loss: 0.138347, Valid Acc: 0.956920,
# Epoch 47. Valid Loss: 0.176173, Valid Acc: 0.957500,
# Epoch 48. Valid Loss: 0.095144, Valid Acc: 0.958800,
# Epoch 49. Valid Loss: 0.138189, Valid Acc: 0.959340,
# Epoch 50. Valid Loss: 0.081956, Valid Acc: 0.958840,
# Epoch 51. Valid Loss: 0.065921, Valid Acc: 0.959640,
# Epoch 52. Valid Loss: 0.083477, Valid Acc: 0.959460,
# Epoch 53. Valid Loss: 0.072577, Valid Acc: 0.961140,
# Epoch 54. Valid Loss: 0.157279, Valid Acc: 0.960520,
# Epoch 55. Valid Loss: 0.058167, Valid Acc: 0.959580,
# Epoch 56. Valid Loss: 0.090206, Valid Acc: 0.959940,
# Epoch 57. Valid Loss: 0.067038, Valid Acc: 0.961020,
# Epoch 58. Valid Loss: 0.038422, Valid Acc: 0.962020,
# Epoch 59. Valid Loss: 0.079111, Valid Acc: 0.961920,
# Epoch 60. Valid Loss: 0.073481, Valid Acc: 0.963100,
# Epoch 61. Valid Loss: 0.044035, Valid Acc: 0.965480,
# Epoch 62. Valid Loss: 0.127407, Valid Acc: 0.965900,
# Epoch 63. Valid Loss: 0.155177, Valid Acc: 0.967600,
# Epoch 64. Valid Loss: 0.113833, Valid Acc: 0.967220,
# Epoch 65. Valid Loss: 0.089963, Valid Acc: 0.966660,
# Epoch 66. Valid Loss: 0.053064, Valid Acc: 0.967840,
# Epoch 67. Valid Loss: 0.055293, Valid Acc: 0.967500,
# Epoch 68. Valid Loss: 0.024663, Valid Acc: 0.966940,
# Epoch 69. Valid Loss: 0.085414, Valid Acc: 0.967420,
# Epoch 70. Valid Loss: 0.065934, Valid Acc: 0.966940,
# Epoch 71. Valid Loss: 0.120088, Valid Acc: 0.967460,
# Epoch 72. Valid Loss: 0.053537, Valid Acc: 0.967240,
# Epoch 73. Valid Loss: 0.029770, Valid Acc: 0.968520,
# Epoch 74. Valid Loss: 0.150694, Valid Acc: 0.968640,
# Epoch 75. Valid Loss: 0.064302, Valid Acc: 0.968060,
# Epoch 76. Valid Loss: 0.042974, Valid Acc: 0.967660,
# Epoch 77. Valid Loss: 0.140194, Valid Acc: 0.968800,
# Epoch 78. Valid Loss: 0.026966, Valid Acc: 0.967940,
# Epoch 79. Valid Loss: 0.125219, Valid Acc: 0.968160,
# Epoch 80. Valid Loss: 0.030156, Valid Acc: 0.968980,
# Epoch 81. Valid Loss: 0.045003, Valid Acc: 0.968960,
# Epoch 82. Valid Loss: 0.080679, Valid Acc: 0.969980,
# Epoch 83. Valid Loss: 0.049812, Valid Acc: 0.970420,
# Epoch 84. Valid Loss: 0.052730, Valid Acc: 0.970300,
# Epoch 85. Valid Loss: 0.067422, Valid Acc: 0.970480,
# Epoch 86. Valid Loss: 0.008704, Valid Acc: 0.970160,
# Epoch 87. Valid Loss: 0.132533, Valid Acc: 0.970180,
# Epoch 88. Valid Loss: 0.077016, Valid Acc: 0.970420,
# Epoch 89. Valid Loss: 0.062167, Valid Acc: 0.969700,
# Epoch 90. Valid Loss: 0.077507, Valid Acc: 0.970820,
# Epoch 91. Valid Loss: 0.175235, Valid Acc: 0.970700,
# Epoch 92. Valid Loss: 0.061993, Valid Acc: 0.970800,
# Epoch 93. Valid Loss: 0.116680, Valid Acc: 0.970120,
# Epoch 94. Valid Loss: 0.109142, Valid Acc: 0.969960,
# Epoch 95. Valid Loss: 0.087664, Valid Acc: 0.971120,
# Epoch 96. Valid Loss: 0.063387, Valid Acc: 0.970820,
# Epoch 97. Valid Loss: 0.132073, Valid Acc: 0.971800,
# Epoch 98. Valid Loss: 0.157375, Valid Acc: 0.971080,
# Epoch 99. Valid Loss: 0.080155, Valid Acc: 0.969300,
# Epoch 100. Valid Loss: 0.034876, Valid Acc: 0.970660,
# Epoch 101. Valid Loss: 0.155055, Valid Acc: 0.971240,
# Epoch 102. Valid Loss: 0.042954, Valid Acc: 0.971840,
# Epoch 103. Valid Loss: 0.025284, Valid Acc: 0.971680,
# Epoch 104. Valid Loss: 0.147129, Valid Acc: 0.970960,
# Epoch 105. Valid Loss: 0.126107, Valid Acc: 0.971260,
# Epoch 106. Valid Loss: 0.013841, Valid Acc: 0.971300,
# Epoch 107. Valid Loss: 0.059203, Valid Acc: 0.971660,
# Epoch 108. Valid Loss: 0.022813, Valid Acc: 0.971420,
# Epoch 109. Valid Loss: 0.062087, Valid Acc: 0.971240,
# Epoch 110. Valid Loss: 0.102344, Valid Acc: 0.972400,
# Epoch 111. Valid Loss: 0.071205, Valid Acc: 0.970540,
# Epoch 112. Valid Loss: 0.032108, Valid Acc: 0.971320,
# Epoch 113. Valid Loss: 0.120445, Valid Acc: 0.970740,
# Epoch 114. Valid Loss: 0.090253, Valid Acc: 0.972120,
# Epoch 115. Valid Loss: 0.065941, Valid Acc: 0.972440,
# Epoch 116. Valid Loss: 0.094795, Valid Acc: 0.972280,
# Epoch 117. Valid Loss: 0.049560, Valid Acc: 0.971960,
# Epoch 118. Valid Loss: 0.072152, Valid Acc: 0.970900,
# Epoch 119. Valid Loss: 0.057576, Valid Acc: 0.972120,
# Epoch 120. Valid Loss: 0.056429, Valid Acc: 0.972140,
# Epoch 121. Valid Loss: 0.066496, Valid Acc: 0.970640,
# Epoch 122. Valid Loss: 0.086945, Valid Acc: 0.971860,
# Epoch 123. Valid Loss: 0.080297, Valid Acc: 0.971420,
# Epoch 124. Valid Loss: 0.018329, Valid Acc: 0.970240,
# Epoch 125. Valid Loss: 0.076523, Valid Acc: 0.973060,
# Epoch 126. Valid Loss: 0.083560, Valid Acc: 0.971980,
# Epoch 127. Valid Loss: 0.003349, Valid Acc: 0.971420,
# Epoch 128. Valid Loss: 0.166455, Valid Acc: 0.971720,
# Epoch 129. Valid Loss: 0.085484, Valid Acc: 0.970960,
# Epoch 130. Valid Loss: 0.050434, Valid Acc: 0.972720,
# Epoch 131. Valid Loss: 0.055478, Valid Acc: 0.972140,
# Epoch 132. Valid Loss: 0.161369, Valid Acc: 0.972520,
# Epoch 133. Valid Loss: 0.038656, Valid Acc: 0.972460,
# Epoch 134. Valid Loss: 0.146942, Valid Acc: 0.971900,
# Epoch 135. Valid Loss: 0.160867, Valid Acc: 0.971140,
# Epoch 136. Valid Loss: 0.107285, Valid Acc: 0.972620,
# Epoch 137. Valid Loss: 0.062424, Valid Acc: 0.971820,
# Epoch 138. Valid Loss: 0.075259, Valid Acc: 0.971240,
# Epoch 139. Valid Loss: 0.065070, Valid Acc: 0.972140,
# Epoch 140. Valid Loss: 0.053987, Valid Acc: 0.970740,
# Epoch 141. Valid Loss: 0.084310, Valid Acc: 0.971500,
# Epoch 142. Valid Loss: 0.089637, Valid Acc: 0.973180,
# Epoch 143. Valid Loss: 0.030454, Valid Acc: 0.971900,
# Epoch 144. Valid Loss: 0.163211, Valid Acc: 0.970100,
# Epoch 145. Valid Loss: 0.198816, Valid Acc: 0.972740,
# Epoch 146. Valid Loss: 0.029139, Valid Acc: 0.971220,
# Epoch 147. Valid Loss: 0.084013, Valid Acc: 0.971580,
# Epoch 148. Valid Loss: 0.100390, Valid Acc: 0.971700,
# Epoch 149. Valid Loss: 0.108326, Valid Acc: 0.971300,
